# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAIK-RAIYAN-2022-CSE/KARE/blob/main/3rd%20Year/NLPT/NLPT_EXP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# WORD EMBEDDING USING TF-IDF RATIO

# %%
import re
import string
import pandas as pd
import math
from functools import reduce
from math import log

# New corpus with provided sentences
corpus = """
The cat is small.
Birds fly high.
Sun is bright.
""".split("\n")[1:-1]
l_A = corpus[0].lower().split()
l_B = corpus[1].lower().split()
l_C = corpus[2].lower().split()

print(l_A)
print(l_B)
print(l_C)
# Out:
# ['the', 'cat', 'is', 'small.']
# ['birds', 'fly', 'high.']
# ['sun', 'is', 'bright.']

# %%
word_set = set(l_A).union(set(l_B)).union(set(l_C))
print(word_set)
# Out:
# {'is', 'fly', 'the', 'sun', 'bright.', 'high.', 'small.', 'cat', 'birds'}

# %%
word_dict_A = dict.fromkeys(word_set, 0)
word_dict_B = dict.fromkeys(word_set, 0)
word_dict_C = dict.fromkeys(word_set, 0)

for word in l_A:
    word_dict_A[word] += 1

for word in l_B:
    word_dict_B[word] += 1

for word in l_C:
    word_dict_C[word] += 1

pd.DataFrame([word_dict_A, word_dict_B, word_dict_C])
# Out:
#    is  fly  the  sun  bright.  high.  small.  cat  birds
# 0   1    0    1    0        0      0       1    1      0
# 1   0    1    0    0        0      1       0    0      1
# 2   1    0    0    1        1      0       0    0      0

# %%
#compute TF
def compute_tf(word_dict, l):
    tf = {}
    sum_nk = len(l)
    for word, count in word_dict.items():
        tf[word] = count/sum_nk
    return tf

tf_A = compute_tf(word_dict_A, l_A)
tf_B = compute_tf(word_dict_B, l_B)
tf_C = compute_tf(word_dict_C, l_C)

pd.DataFrame([tf_A, tf_B, tf_C])
# Out:
#          is       fly   the       sun   bright.     high.  small.   cat  \
# 0  0.250000  0.000000  0.25  0.000000  0.000000  0.000000    0.25  0.25
# 1  0.000000  0.333333  0.00  0.000000  0.000000  0.333333    0.00  0.00
# 2  0.333333  0.000000  0.00  0.333333  0.333333  0.000000    0.00  0.00
#
#       birds
# 0  0.000000
# 1  0.333333
# 2  0.000000

# %%
#compute IDF
def compute_idf(strings_list):
    n = len(strings_list)  # Total number of documents
    idf = dict.fromkeys(strings_list[0].keys(), 0)  # Initialize IDF dictionary

    # Calculate the document frequency (DF) for each word
    for l in strings_list:
        for word, count in l.items():
            if count > 0:
                idf[word] += 1

    # Calculate the IDF for each word using log base 2
    for word, df in idf.items():
        if df > 0:
            idf[word] = math.log2(n / float(df))
        else:
            idf[word] = 0  # Handle cases where the word is not in any document

    return idf

idf = compute_idf([word_dict_A, word_dict_B, word_dict_C])
pd.DataFrame([idf])
# Out:
#          is       fly       the       sun   bright.     high.    small.  \
# 0  0.584963  1.584963  1.584963  1.584963  1.584963  1.584963  1.584963
#
#         cat     birds
# 0  1.584963  1.584963

# %%
#compute TF-IDF ratio
def compute_tf_idf(tf, idf):
    tf_idf = dict.fromkeys(tf.keys(), 0)
    for word, v in tf.items():
        tf_idf[word] = v * idf[word]
    return tf_idf

tf_idf_A = compute_tf_idf(tf_A, idf)
tf_idf_B = compute_tf_idf(tf_B, idf)
tf_idf_C = compute_tf_idf(tf_C, idf)

#print the TF-IDF ratio
pd.DataFrame([tf_idf_A, tf_idf_B, tf_idf_C])
# Out:
#          is       fly       the       sun   bright.     high.    small.  \
# 0  0.146241  0.000000  0.396241  0.000000  0.000000  0.000000  0.396241
# 1  0.000000  0.528321  0.000000  0.000000  0.000000  0.528321  0.000000
# 2  0.194988  0.000000  0.000000  0.528321  0.528321  0.000000  0.000000
#
#         cat     birds
# 0  0.396241  0.000000
# 1  0.000000  0.528321
# 2  0.000000  0.000000

# %%
#WORD EMBEDDING USING BAG-OF-WORDS (BoW)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
Text = """
The cat is small.
Birds fly high.
Sun is bright.
"""
# TOKENIZATION
sentences = sent_tokenize(Text)
sentences = [sent.lower().replace(".","") for sent in sentences]
print('Our Corpus:',sentences)
#CountVectorizer : Convert a collection of text documents to a matrix of token counts.
count_vect = CountVectorizer()
# fit & transform will represent each sentences as BOW representation
BOW = count_vect.fit_transform(sentences)
# Get the vocabulary
print("Our vocabulary: ", count_vect.vocabulary_)
#see the BOW representation
print(f"BoW representation for {sentences[0]} {BOW[0].toarray()}")
print(f"BoW representation for {sentences[1]} {BOW[1].toarray()}")
print(f"BoW representation for {sentences[2]} {BOW[2].toarray()}")
# BOW representation for a new text
BOW_ = count_vect.transform(["Hotel review is nice"])
print("Bow representation for 'Hotel review is nice':", BOW_.toarray())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Our Corpus: ['\nthe cat is small', 'birds fly high', 'sun is bright']
# Our vocabulary:  {'the': 8, 'cat': 2, 'is': 5, 'small': 6, 'birds': 0, 'fly': 3, 'high': 4, 'sun': 7, 'bright': 1}
# BoW representation for
# the cat is small [[0 0 1 0 0 1 1 0 1]]
# BoW representation for birds fly high [[1 0 0 1 1 0 0 0 0]]
# BoW representation for sun is bright [[0 1 0 0 0 1 0 1 0]]
# Bow representation for 'Hotel review is nice': [[0 0 0 0 0 1 0 0 0]]

# %%
# WORD EMBEDDING USING n-GRAMS

# %%
from nltk import ngrams
text = input("Enter your sentence: ")
n = int(input("Enter the value of n: "))
n_grams = ngrams(text.split(),n)
for grams in n_grams:
  print(grams)
# Out:
# Enter your sentence: The cat is small
# Enter the value of n: 2
# ('The', 'cat')
# ('cat', 'is')
# ('is', 'small')
